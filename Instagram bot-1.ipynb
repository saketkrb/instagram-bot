# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
import time
from selenium.common.exceptions import NoSuchElementException

# %%
driver = webdriver.Chrome(executable_path = '/Users/saket/Downloads/chromedriver')
driver.get('https://www.instagram.com/')
driver.maximize_window()
time.sleep(5)

# %% [markdown]
# <!-- Submit with sample username and password
#
# Handling save passwords and turn on notification windows  -->

# %%
# log in and remmeber browser off
username = 'sample_username'
password = 'sample_password'
input1 = driver.find_element_by_name('username')
input2 = driver.find_element_by_name('password')
input1.send_keys(username)
input2.send_keys(password)
input2.submit()
# sqdOP yWX7d    y3zKF     
timestamp=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "sqdOP")))
time.sleep(3)
driver.find_element_by_class_name('sqdOP').click()
timestamp=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "HoLwm")))
driver.find_element_by_xpath('//button[contains(@class, "HoLwm")]').click()

# %% [markdown]
# <!-- Type for “food” in search bar and printing all the names of the Instagram Handles that are displayed in list after typing “food” -->

# %%
timestamp=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "x3qfX")))
search_keyword = 'food'
search = driver.find_element_by_class_name('x3qfX')
search.send_keys(search_keyword)
# time.sleep(2)
timestampe=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '//a[@class="yCE8d  "]/div/div[2]/div/span')))

# %%
for i in driver.find_elements_by_xpath('//a[@class="yCE8d  "]/div/div[2]/div/span'):
    print(i.get_attribute('innerHTML'))
# Out:
# yourfoodlab
# foodnetwork
# buzzfeedfood
# foodtalkindia
# foodrush.recipe
# food_hippies95
# food
# food.darzee
# sailusfood
# foodtrb
# foodlamour
# __food_quest__
# foodon0
# foodandwine
# ndtv_food
# thisisdelhi
# foodhallindia
# delhifoodwalks
# food_bengaluru
# foodpandaindia
# elavegan
# food__auditor
# food_and_bengaluru
# karnataka.food.diaries
# food._.rush
# foodart2020
# food___gourmet
# singletoki
# so_deliciouslytasty
# foodloversindia
# food_n_fork
# food_maga
# insanewiches_
# foodart2k17
# food_feverforever
# food_techie
# food_steps040
# thewholetruthfoods
# watchintheknowfood
# uvaizzzz
# fed.india
# food_frisson
# food.destinationz
# Food
# foodofkarnataka
# foodizs
# foodswingz_
# Food and Agriculture Organization of the United Nations (FAO)
# food_gasmicc

# %% [markdown]
# # visiting so delhi , follow/unfollow

# %%
driver.find_element_by_class_name('aIYm8').click() #clear input
timestamp=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "x3qfX"))) 
time.sleep(1)
search_keyword = 'So Delhi'
search = driver.find_element_by_class_name('x3qfX')
search.send_keys(search_keyword)
timestamp=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "x3qfX")))
driver.find_element_by_xpath('//a[contains(@class, "yCE8d")]').click()

# %%
timestamp=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "_6VtSN")))
# waiter=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "_6VtSN")))

# %%
if driver.find_element_by_class_name('_6VtSN').get_attribute('innerHTML')=='Following':
    print('You are already following the page!')
else:
    driver.find_element_by_xpath('//button[contains(@class, "_6VtSN")]').click()
timestamp=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "_6VtSN")))
time.sleep(3)

# %% [markdown]
# # Unfollowing so delhi

# %%
driver.find_element_by_xpath('//button[contains(@class, "_5f5mN")]').click()      
timestamp=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "_7UhW9")))
driver.find_element_by_xpath('//button[contains(@class, "aOOlW -Cab_   ")]').click()

# %%
driver.find_element_by_class_name('TqC_a').click()
timestamp=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "XTCLo")))

# %%
search_box=driver.find_element_by_class_name('XTCLo')
search_box.send_keys('dilsefoodie')
timestamp=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "yCE8d")))
driver.find_element_by_class_name('yCE8d').click()
time.sleep(5)

# %%
driver.execute_script('window.scrollBy(0, 3000);')
time.sleep(2.5)
driver.execute_script('window.scrollBy(0, 3000);')
time.sleep(2.5)
waiter=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '//div[contains(@class, "Nnq7C")]/div/a/div[1]')))

# %%
#liking 30 posts
count=0
for i in driver.find_elements_by_xpath('//div[contains(@class, "Nnq7C")]/div/a/div[1]'):
    i.click()
    trier=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH,
                                                                    "//button[contains(@class, 'dCJp8')]")))
    
    try:
        WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, '//section[contains(@class, "ltpMr")]')))
        time.sleep(0.8)
        driver.find_element_by_xpath('//button[contains(@class, "dCJp8")]/span[contains(@class, "glyphsSpriteHeart__outline__24__grey_9")]').click()
    except NoSuchElementException:
        print('Already Liked!')
    driver.back()
    count+=1
    if count==30:
        print('Liked All(30)!')
        break
waiter=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '//div[contains(@class, "Nnq7C")]/div/a/div[1]')))
time.sleep(2)
driver.execute_script('window.scrollTo(0, 0)')

# %%
#unliking 30 posts
count=0
for i in driver.find_elements_by_xpath('//div[contains(@class, "Nnq7C")]/div/a/div[1]'):
    i.click()
    trier=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH,
                                                                    "//button[contains(@class, 'dCJp8')]")))
    
    try:
        WebDriverWait(driver, 5).until(EC.presence_of_element_located((By.XPATH, '//section[contains(@class, "ltpMr")]')))
        driver.find_element_by_xpath('//button[contains(@class, "dCJp8")]/span[contains(@class, "glyphsSpriteHeart__filled__24__red_5")]').click()
    except NoSuchElementException:
        print('Already UnLiked!')
    driver.back()
    count+=1
    time.sleep(0.3)
    if count==30:
        print('UnLiked All(30)!')
        break
time.sleep(2)

# %% [markdown]
# <!-- geting username of first 500 followers of sodelhi -->

# %%
driver.find_element_by_class_name('TqC_a').click()
waiter=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "XTCLo")))
search_box=driver.find_element_by_class_name('XTCLo')
search_box.send_keys('So Delhi')
waiter=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "yCE8d")))
driver.find_element_by_class_name('yCE8d').click()
waiter=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "_6VtSN")))
time.sleep(3)

# %%
try:
    driver.execute_script('window.scrollTo(0, 0)')
    driver.find_element_by_xpath('//a[@class="-nal3 "]/span[@class="g47SY "]').click()
except NoSuchElementException:
    driver.find_element_by_xpath('//a[@class=" _81NM2"]/span[contains(@class, "g47SY")]').click()
waiter=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '//a[contains(@class, "notranslate")]')))

# %%
while True:
    try:
        sodelhi=[]
        count=0
        while True:
            elements=driver.find_elements_by_xpath('//a[contains(@class, "notranslate")]')
            if len(elements)<500:
                waiter=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.XPATH, '//ul[contains(@class, "jSC57")]')))
                driver.execute_script('arguments[0].scrollIntoView(0, 100);', driver.find_element_by_xpath('//ul[contains(@class, "jSC57")]'))
                time.sleep(0.8)
            i=elements[count]
            sodelhi.append(i.get_attribute('innerHTML'))
            if len(sodelhi)>=500:
                break
            count+=1
        break
    except StaleElementReferenceException:
        continue
sodelhi
# Out:
# ['_mamtaagrawal_',
#  'gym_karachi',
#  'memon_.usama',
#  '20.isha',
#  'anjali1087',
#  'mihir_babbar',
#  'shad.ab215',
#  'raghugurjar645',
#  'fierce_damsel',
#  'mruthyunjay_sk',
#  'dhruv.saxena945',
#  'shalu.goyal1990',
#  'divya.sood99',
#  'sharma_ananya_07',
#  'boho_decorr',
#  'maahi.khan.585112',
#  'anki_2230',
#  '_._.a.y.u.s.h.i._._',
#  'rocky_handsome706',
#  'heartbroken5649',
#  'anujprakashjagtap',
#  'king_________________nagar',
#  'no.ushad20',
#  'jhilmillpathak',
#  'ajayy9534',
#  'ramtanic',
#  'spidynikhil',
#  'asianfarm_shack',
#  'pankajjangir61',
#  'hsanka653',
#  'preetijuliustigga',
#  'healthcolony',
#  'parajmongia',
#  'dr.dabasanurag',
#  'aliabbas5943',
#  'hamida.kanpuraw',
#  'mr.shivam_pandat',
#  'sahilverma9745',
#  'bagui._._.pritii',
#  'shreya_sera16',
#  'rathanupama1',
#  '_sugarblossomhugs_',
#  'snehu__71',
#  'prakriti_khatri',
#  'sukhaleshyadav',
#  'quot_emotivation',
#  'ps_solanki96',
#  'free_fire_id_seller._',
#  'nandinisharmaaaa',
#  'bhumani.tyagi',
#  'dastenukee',
#  'affaneze',
#  'mrcrazy653',
#  '__chhavii___',
#  'suraj.kharwar.169067',
#  'naina22785',
#  '_somya12_',
#  'adultrywine',
#  'mr.joker_g',
#  'vishuvishu221',
#  'chaos_stillness',
#  'dsuza19941',
#  'neelaveni510',
#  '_toinfinity_ndbeyond_',
#  'lakshittaverma18',
#  'thebargainstory',
#  'pifipizzadelhi',
#  'm.ashfaq05',
#  '__smridhi',
#  'badbo_y4554',
#  'trishna9723',
#  'kanishq_basoya_dellhii0001',
#  'hiteshj_jain',
#  'dr_sonakshi',
#  'deepanshi6260',
#  'mansi02338',
#  'iamdivyanshubansal',
#  'samhitasinha',
#  'larisagorkavenko',
#  'shoutout_daily_hd',
#  'jainabhivyakti',
#  'ranirani5151',
#  'karanpropmart',
#  'yogeshsharma5116',
#  'nimishkshettry',
#  'dilliwaledilwale',
#  'the_lastoftherealones_',
#  'heath.guru.spa',
#  '_taanyaaaa',
#  'sheraq786',
#  'smiling_hitesh',
#  'sanskriti_creation_',
#  'bhati.dheerajsingh',
#  'jubishjovial',
#  'sonam_sahni_',
#  '_uzma__syed__',
#  'shriishti_gupta',
#  'crazy_ancy.1999',
#  'ranjanyadav9829',
#  'vrma__neha',
#  'leena_arora06',
#  'sky_arora87',
#  'vaishnav8603',
#  'kaushikeee_',
#  'sidmehta__',
#  'cryptovintage',
#  'snaya22294',
#  'adityagtripathi',
#  '_._.vilen',
#  'pubg_mobile_addaa_',
#  'bhand_bhature',
#  'naksh9331',
#  'itskaurbatth',
#  'triphikes',
#  'manojkumarsingh00811981',
#  'prakarshjn',
#  'shahwaj297',
#  'rajji90',
#  'my_macroni',
#  'shrey_aggarwl',
#  'shreyajain8196',
#  'sh.ii.vam',
#  'parmeetsingh07',
#  '_wefashionhub_',
#  'taarni_thakur',
#  'ginnimahi2',
#  'nainabansal40',
#  'sachinsinghking',
#  'kasif.malik786',
#  'mohamed.hajir.school',
#  'shivani7_gupta',
#  'vishad_malik',
#  'dillifilmco',
#  'ajohn515',
#  'marketjarindia',
#  'lovely_boyharshu',
#  'sumikdutta',
#  'hamidshafiqe',
#  'abbasitalha210',
#  'zair.a688',
#  'your_.fashion_.factory',
#  'saurabhed_',
#  'anita84__sharma',
#  'arpita_p_22',
#  'keshri554',
#  'simrandureja524',
#  'akansha.kansal.1',
#  'thinkingthunder',
#  'amazon_associate_as21',
#  'ab.hi5456',
#  'the_wardrobe642',
#  'rana_saahab',
#  'prasenjitadhikari1',
#  'aka.one4',
#  'ishakkhan15662020',
#  'ekkalakaar',
#  'gurnamdeepkaur',
#  'viralmixvideos',
#  'liberal_foodie',
#  'garv.kindra83',
#  'iam_ankurgupta',
#  'beautyfabrics_',
#  'myselfvijaymonu',
#  'silentlover_35',
#  'virajrathod_23',
#  'akanshaagrawalll',
#  'nitish10rathore',
#  'nikhil_yadav_1441',
#  'harishgoswami23',
#  'memerhunyr',
#  'team_shinchan2',
#  'rachit6725',
#  'govindsingh5383',
#  'parth_thakar',
#  'they_just_said',
#  'shabaz._rana',
#  'ankush.ruhela',
#  '_mr_karoliya_',
#  'ar.ayush_anand',
#  'azeem.chauhan.96',
#  'pria_jaiswal',
#  'mr_khan__mohin',
#  'akanshalal114199',
#  'vridhibyshrida',
#  'creative.club',
#  'vague_screams',
#  'theindianguide',
#  'saniapatelll',
#  'rahul_dulmana0363',
#  'nagrajnavnita',
#  '_nirmali',
#  'santosh1993k',
#  'blissofsoull',
#  'monu_nagar7',
#  'saransharastogi',
#  'piyushhh_10',
#  'tanejaheena',
#  '_shefali.prajapati_',
#  'quotesofbawarchi',
#  'kaavya_mishra112',
#  'sudiksha.thusu',
#  'shakshi_2609',
#  'reel_only1',
#  'sandwichking_sector4',
#  'robinbansalofficial',
#  'gautamkhurana01',
#  'manjari.rai',
#  'kanikabhatiazx',
#  'happysoul_soulful',
#  'ikk___kudii',
#  'thesabzbagh',
#  'toto_the_traveller_',
#  '_mancce_',
#  'i_mdhairyakaushik',
#  'meeshaa.1',
#  'neekhrakushagra',
#  'golgappa.art',
#  'su_mit7499',
#  'jayantriya',
#  '__dev_sarkar__',
#  'khusbu_kejriwal',
#  'gcs9950',
#  'hk9166196',
#  'sachinkaushik671',
#  'mohdali8195',
#  'salman.ansari9540077090gmail.6',
#  'anju_ravi90',
#  'yours.truly.anirudh',
#  'homemadeyummyfoodzz7',
#  'anuj_thapliyal99',
#  'naina117_',
#  'acreshomeindia',
#  'monukhan4075',
#  'rishabh_r5',
#  'shahrukh_jaani_89',
#  'pra_kriti_10sharma',
#  'namrata_bharti3',
#  'rahulpal_0001',
#  'scorpion_reen_kapoor',
#  'thebaristagal',
#  'rohan1262.2017',
#  'solivagant25',
#  'adarshrexwal6202347652',
#  'siddhantsensei',
#  'nagmanisalendra',
#  'amitranaaaa',
#  'stuff5036',
#  'tastetotastiest',
#  'pubg_player_2000000',
#  'borken.056',
#  'sehajaroraaa_',
#  'saurpat3',
#  '_shreyasethi_',
#  'sonu_khosya_mayee',
#  'mr.jassh',
#  'masumsingh561',
#  'inatashakhurana',
#  'rauniyar.shelly',
#  'banjaran_01',
#  'gurpreet_kaur_randhawa25',
#  '_geetikaa',
#  'deshwal.deshwal.50159',
#  'karishmamakeups',
#  'shivaangityagi16',
#  'iamnikhildeol',
#  'himanshu_aggarwal_987',
#  'sylvanaesatpathy',
#  'ritu_shama',
#  'golu8022',
#  'raj_deep2002',
#  'dhruvmalik09',
#  'para.s3495',
#  'sodhi2307',
#  'vibu_04',
#  'arshdeepsingh111',
#  'parulsharma.__',
#  'rounak_kumar08',
#  'safar_aur_chai',
#  'pradhumraj0',
#  'vinksss',
#  'shrutii.24',
#  'shheeetall_',
#  'ms.ordinarie',
#  'kukreja_himanshhhu',
#  'riyaa_sharma23',
#  'rahulyaduvanshi434',
#  'anshulsinghal25',
#  'northland_adventure_india',
#  'more_of_mohak',
#  'khanbaba6251',
#  '_._anchal._',
#  'mem_ematerial',
#  'life_hakuna_matata_',
#  'swastikaapaul',
#  'suman_gupta2642',
#  'food_king_ac',
#  'rukminibarua',
#  'sagarsaroj27',
#  'sunnykashyap37836',
#  'shilpitoppo',
#  'terahero344',
#  'nitin_s_1491',
#  '2019sagarsinghrajput',
#  'namanpr234',
#  'bhawana.tiwari',
#  'vintyagi',
#  'im_unheardwrites',
#  'mitu.varma',
#  'sumitsonawane43',
#  'batrahomes',
#  'meghusrivastava',
#  'rishiikaagarwal',
#  'shivaymishra19',
#  'mobilesetup',
#  '_urvichudasama',
#  'prince_mangary',
#  'amrjeetpoddar',
#  'art_for_art_sake22',
#  'am_kunal',
#  'crezy_cuty_386',
#  'smrtrls38',
#  's14ushi',
#  'akash_ji98',
#  'arya2371',
#  'camerawaliwomaniya',
#  '____faizu_',
#  'balwant.singhmakkar',
#  'varundewan219',
#  'priya.momo',
#  'muskan__roy12',
#  'shiv_shambhu1211',
#  'ch_mona72',
#  'ranjitraj383',
#  'sanjeevsunny12',
#  'nandanyogesh92',
#  'dad_of_devil02',
#  'lokeshofficiel',
#  'vagmivashist_3221',
#  'parshva1994',
#  'shaur1999',
#  'ajaymathur0030',
#  'lavishyadavs',
#  'yummytite',
#  'balwinder__1313',
#  'trip.sharma',
#  'memes_lockk',
#  'naruladitya',
#  'k2k_kitchen_studio',
#  'omn.india',
#  'mysticle._.dimple13',
#  'tushar.vasistha',
#  'salim.khan00',
#  'bonbon.chocolates',
#  'salmansalmani673',
#  'beingsannyasi',
#  'jaipuri__thaalii',
#  'sunil_love_you',
#  'randhir5339',
#  'angelcf759',
#  'misrabhishek',
#  'svkgupta',
#  'shwetasharma.10',
#  'palak_guglani21',
#  'kartik.asri',
#  'simerjit_malhotra',
#  'zaranoor832',
#  'melting.stories',
#  'sahilkhurana18',
#  'ispita_har',
#  'sumedh.james',
#  'bhavsmits',
#  'helhoehell',
#  'sarfarazaahmad',
#  'mukul_mishra02',
#  'jasskaur_9313',
#  'foodpoint933',
#  'swassstikkk',
#  'raffish.abhi',
#  'that_wild_flower_',
#  '_thewildspirit_',
#  'saab.kairon.7',
#  '7173.ankit',
#  'kristae11',
#  'sheetal_bisht56',
#  'sirfiri_',
#  'phonics.peekaboo',
#  'khushi.bhatnagar',
#  'nareshpathour',
#  'pratisthajena',
#  'ammy_dhawale',
#  'rishabhdeal',
#  'xyz_5456',
#  'panti5705',
#  'thakur._bhanu_pratap_singh',
#  'virajgupta120',
#  'az__shk',
#  'thesaisha_',
#  'fil.igran',
#  'gemegha',
#  'hemantb3',
#  'irshad.afride',
#  'vicky5748kumar',
#  'kumar.aakriti',
#  'siddharthtyagi7',
#  'deepalismahajan',
#  'xpose_check',
#  'varma_saksham',
#  'prakriti_k',
#  'sonam_lal',
#  'ashishchaursi',
#  'abhishoook',
#  '_shiva__writer_',
#  'bharti_1220_',
#  'official_mr_romiyo',
#  'mansi._singh15',
#  'malhotramanav9',
#  '_im_sahil_verma_',
#  'squiggles.del',
#  'ku_ldeep2159',
#  'jiyoraw.cold.pressed.oil',
#  'rkvmahasangh',
#  'arya_value_bazaar',
#  'kahkashakohinoor05',
#  'mahee_060',
#  'adityakamra9958',
#  'shah_surabhi',
#  'natureloverdelhi',
#  'qaafabags',
#  'nikhil.1423',
#  'radhesh_sarma',
#  'happywrites654',
#  'x_amar_xshingniya',
#  'bdeepanshu66',
#  'initcafe',
#  'rajatj204',
#  'abhinavtrivedi93',
#  'hayatnabi9500',
#  'rk8941282',
#  'cute_boy__0044',
#  'kajal.bohat.568',
#  'champ_always',
#  '_sagargautam',
#  'namangupta.2303',
#  '_adirao_',
#  'sonuraj.175',
#  'viisheshh__06',
#  'azadtuber',
#  'simranbedi801',
#  'mr_lakshuu',
#  'ar_jewels_',
#  'cryptic._human',
#  'ruchikabehera17',
#  'sk2334357',
#  'harsh.pvvttt',
#  'dixonr19',
#  'vaishnavi.yadav',
#  'itz_jerry_09',
#  'fuckgirl3549',
#  'akshat_s10',
#  'sarthakrana',
#  'youth.for.a.change',
#  'hardik__verma989',
#  'label_by_ridhisood',
#  'madartcommunication',
#  'achin_jain2001',
#  'sanskrity_jain',
#  'sunmeet2409',
#  'inaarya_organics',
#  'jyotsanakhetarpal',
#  'rwt_bhanu28',
#  'pahwakarann',
#  'photographersofdelhi',
#  'kaalyaatri',
#  'sanjutanwar38',
#  'parthgupta_6342',
#  'private_jet_tour_',
#  'orangestoreindia',
#  'bakingcolours',
#  'bakersladder',
#  'love34356',
#  'hoosiermummy',
#  'bangaaaa25',
#  '___raghavk___',
#  'ekta.kh',
#  'khushi_panchal111',
#  'zaara_ahmed15',
#  'artworkfollower',
#  'jeet_singh_5',
#  'officialpriyanka_r',
#  'banjara.foodies',
#  'nagpal_upasana',
#  'dhawancheenu',
#  'cravy_dessertss',
#  'chatrathsidharth',
#  '_rishupandey_11',
#  'sradhaskitchen',
#  'ricky.ramgarhia66',
#  'ca_ndy4740',
#  '_ishamakhija_',
#  'anita_feasts']

# %%
driver.find_element_by_class_name('glyphsSpriteX__outline__24__grey_9').click()
waiter=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "TqC_a")))

# %% [markdown]
# # Visiting Coding Ninjas and checking their story with given conditions:

# %%
driver.find_element_by_class_name('TqC_a').click()

search_box=driver.find_element_by_class_name('XTCLo')
search_box.send_keys('coding.ninjas')
waiter=WebDriverWait(driver, 10).until(EC.presence_of_element_located((By.CLASS_NAME, "yCE8d")))

# %%
driver.find_element_by_class_name('yCE8d').click()
time.sleep(3)

# %%
try:
    if int(driver.find_element_by_xpath('//div[contains(@class, "h5uC0")]/canvas').get_attribute('height'))==168:
        print('You have not seen the story yet!')
        driver.find_element_by_xpath('//div[contains(@class, "h5uC0")]').click()
    elif int(driver.find_element_by_xpath('//div[contains(@class, "h5uC0")]/canvas').get_attribute('height'))==166:
        print('You have already seen the story!')
except NoSuchElementException:
    pass
# Out:
# You have not seen the story yet!
